# %%
import numpy as np
import pandas as pd

# %%
dataframe = pd.read_csv("https://raw.github.com/mattdelhey/kaggle-titanic/master/Data/train.csv")

# %%
dataframe.head(25)
# Out:
#     survived  pclass                                               name  \
# 0          0       3                            Braund, Mr. Owen Harris
# 1          1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2          1       3                             Heikkinen, Miss. Laina
# 3          1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4          0       3                           Allen, Mr. William Henry
# 5          0       3                                   Moran, Mr. James
# 6          0       1                            McCarthy, Mr. Timothy J
# 7          0       3                     Palsson, Master. Gosta Leonard
# 8          1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9          1       2                Nasser, Mrs. Nicholas (Adele Achem)
# 10         1       3                    Sandstrom, Miss. Marguerite Rut
# 11         1       1                           Bonnell, Miss. Elizabeth
# ...

# %%
dataframe['age'].mean()
# Out:
# 29.69911764705882

# %%
dataframe['pclass'].value_counts()
# Out:
# pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
dataframe.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
dataframe[(dataframe['age']<20) & (dataframe['pclass'] == 3)]
# Out:
#      survived  pclass                                  name     sex   age  \
# 7           0       3        Palsson, Master. Gosta Leonard    male   2.0
# 10          1       3       Sandstrom, Miss. Marguerite Rut  female   4.0
# 14          0       3  Vestrom, Miss. Hulda Amanda Adolfina  female  14.0
# 16          0       3                  Rice, Master. Eugene    male   2.0
# 22          1       3           McGowan, Miss. Anna "Annie"  female  15.0
# ..        ...     ...                                   ...     ...   ...
# 852         0       3               Boulos, Miss. Nourelain  female   9.0
# 855         1       3            Aks, Mrs. Sam (Leah Rosen)  female  18.0
# 869         1       3       Johnson, Master. Harold Theodor    male   4.0
# 875         1       3      Najib, Miss. Adele Kiamie "Jane"  female  15.0
# 877         0       3                  Petroff, Mr. Nedelio    male  19.0
#
#      sibsp  parch   ticket     fare cabin embarked
# ...

# %%
dataframe['2024_inr_fare'] = dataframe['fare'] * 143.15

# %%
dataframe.head(30)
# Out:
#     survived  pclass                                               name  \
# 0          0       3                            Braund, Mr. Owen Harris
# 1          1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2          1       3                             Heikkinen, Miss. Laina
# 3          1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4          0       3                           Allen, Mr. William Henry
# 5          0       3                                   Moran, Mr. James
# 6          0       1                            McCarthy, Mr. Timothy J
# 7          0       3                     Palsson, Master. Gosta Leonard
# 8          1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9          1       2                Nasser, Mrs. Nicholas (Adele Achem)
# 10         1       3                    Sandstrom, Miss. Marguerite Rut
# 11         1       1                           Bonnell, Miss. Elizabeth
# ...

# %%
print("Survival percentage of third class passengers aged less than 20: ",end="")
print(float(dataframe[(dataframe['age']<20) & (dataframe['pclass'] == 3)]['survived'].sum() / dataframe[(dataframe['age']<20) & (dataframe['pclass'] == 3)]['survived'].count())*100)
# Out:
# Survival percentage of third class passengers aged less than 20: 33.33333333333333

# %%
print("Survival percentage of first class passengers aged less than 20: ",end="")
print(float(dataframe[(dataframe['age']<20) & (dataframe['pclass'] == 1)]['survived'].sum() / dataframe[(dataframe['age']<20) & (dataframe['pclass'] == 1)]['survived'].count())*100)
# Out:
# Survival percentage of first class passengers aged less than 20: 80.95238095238095
